# %% [raw]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Visualization
# import matplotlib.pyplot as plt
# plt.style.use('seaborn-darkgrid')  #darkgrid , whitegrid , dark , white , and ticks
# import seaborn as sns
#
# import warnings
# warnings.filterwarnings('ignore')
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [raw]
# train = pd.read_csv('/kaggle/input/titanic/train.csv')
# test = pd.read_csv('/kaggle/input/titanic/test.csv')
# gender_submission = pd.read_csv('/kaggle/input/titanic/gender_submission.csv')

# %%
# bibliotecas manipulaçao de dados
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
from IPython.core.display import display, HTML

# bibliotecas de Visualização
import matplotlib.pyplot as plt
plt.style.use('seaborn-darkgrid')  #darkgrid , whitegrid , dark , white , and ticks 
import seaborn as sns
display(HTML("<style>.container {width:100% !important; }</style>"))

# maximiza o número de colunas e linhas para impressão 
# quando do uso da função head() do pandas
pd.options.display.max_columns = 15
pd.options.display.max_rows = 50
import warnings
warnings.filterwarnings('ignore')
# Out:
# /tmp/ipykernel_97541/590801654.py:8: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-darkgrid')  #darkgrid , whitegrid , dark , white , and ticks
# <style>.container {width:100% !important; }</style>

# %%
train = pd.read_csv(r'../titanic/data/train.csv')
test = pd.read_csv(r'../titanic/data/test.csv')
gender_submission = pd.read_csv(r'../titanic/data/kaggle_submission.csv')

# %%
train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
test.head()
# Out:
#    PassengerId  Pclass                                          Name     Sex  \
# 0          892       3                              Kelly, Mr. James    male
# 1          893       3              Wilkes, Mrs. James (Ellen Needs)  female
# 2          894       2                     Myles, Mr. Thomas Francis    male
# 3          895       3                              Wirz, Mr. Albert    male
# 4          896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female
#
#     Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 0  34.5      0      0   330911   7.8292   NaN        Q
# 1  47.0      1      0   363272   7.0000   NaN        S
# 2  62.0      0      0   240276   9.6875   NaN        Q
# 3  27.0      0      0   315154   8.6625   NaN        S
# 4  22.0      1      1  3101298  12.2875   NaN        S

# %%
gender_submission.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
#Save PassengerId to assist in creating the file that will be sent to Kaggle
passengerId = test['PassengerId']

# %%
# Creating a new DF with Train and test
titanic_df = train._append(test, ignore_index=True)

# %%
# Apresentar Cabeçalho
display(HTML('<H3><B>BASE DE DADOS TITANIC<b></h3></hr>'))
# CONSTANTES
NUM_POPULACAO = titanic_df.shape[0]
NUM_ATRIBUTOS = titanic_df.shape[1]

# Carregando 1o amostras aleatórias
display(titanic_df.sample(10))
display(HTML('<hr/><b>População: </b>' + 
             str(NUM_POPULACAO) +
             ' | Númeor de Atributos: ' +
             str(NUM_ATRIBUTOS)  + '</H3>'))
# Out:
# <H3><B>BASE DE DADOS TITANIC<b></h3></hr>
#       PassengerId  Survived  Pclass  \
# 728           729       0.0       2
# 429           430       1.0       3
# 656           657       0.0       3
# 1246         1247       NaN       1
# 868           869       0.0       3
# 383           384       1.0       1
# 1008         1009       NaN       3
# 733           734       0.0       2
# 214           215       0.0       3
# 393           394       1.0       1
#
#                                                    Name     Sex   Age  SibSp  \
# 728                     Bryhl, Mr. Kurt Arnold Gottfrid    male  25.0      1
# 429                  Pickard, Mr. Berk (Berk Trembisky)    male  32.0      0
# 656                               Radeff, Mr. Alexander    male   NaN      0
# 1246                           Julian, Mr. Henry Forbes    male  50.0      0
# 868                         van Melkebeke, Mr. Philemon    male   NaN      0
# 383   Holverson, Mrs. Alexander Oskar (Mary Aline To...  female  35.0      1
# 1008                    Sandstrom, Miss. Beatrice Irene  female   1.0      1
# 733                          Berriman, Mr. William John    male  23.0      0
# 214                                 Kiernan, Mr. Philip    male   NaN      1
# 393                              Newell, Miss. Marjorie  female  23.0      1
#
#       Parch             Ticket      Fare Cabin Embarked
# 728       0             236853   26.0000   NaN        S
# 429       0  SOTON/O.Q. 392078    8.0500   E10        S
# 656       0             349223    7.8958   NaN        S
# 1246      0             113044   26.0000   E60        S
# 868       0             345777    9.5000   NaN        S
# 383       0             113789   52.0000   NaN        S
# 1008      1            PP 9549   16.7000    G6        S
# 733       0              28425   13.0000   NaN        S
# 214       0             367229    7.7500   NaN        Q
# 393       0              35273  113.2750   D36        C
# <hr/><b>População: </b>1309 | Númeor de Atributos: 12</H3>

# %%
# Missing
titanic_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age             263
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# dtype: int64

# %%
# type data
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  1309 non-null   int64
#  1   Survived     891 non-null    float64
#  2   Pclass       1309 non-null   int64
#  3   Name         1309 non-null   object
#  4   Sex          1309 non-null   object
#  5   Age          1046 non-null   float64
#  6   SibSp        1309 non-null   int64
#  7   Parch        1309 non-null   int64
#  8   Ticket       1309 non-null   object
#  9   Fare         1308 non-null   float64
#  10  Cabin        295 non-null    object
#  11  Embarked     1307 non-null   object
# dtypes: float64(3), int64(4), object(5)
# memory usage: 122.8+ KB

# %%
# estictis data
titanic_df.describe().style.background_gradient(cmap = "Purples_r")
# Out:
# <style type="text/css">
# #T_3d14e_row0_col0, #T_3d14e_row0_col1, #T_3d14e_row0_col2, #T_3d14e_row0_col3, #T_3d14e_row0_col4, #T_3d14e_row0_col5, #T_3d14e_row0_col6, #T_3d14e_row7_col0 {
#   background-color: #fcfbfd;
#   color: #000000;
# }
# #T_3d14e_row1_col0, #T_3d14e_row5_col0 {
#   background-color: #9e9bc8;
#   color: #f1f1f1;
# }
# #T_3d14e_row1_col1, #T_3d14e_row1_col2, #T_3d14e_row1_col4, #T_3d14e_row1_col5, #T_3d14e_row2_col1, #T_3d14e_row2_col2, #T_3d14e_row2_col4, #T_3d14e_row2_col5, #T_3d14e_row3_col0, #T_3d14e_row3_col1, #T_3d14e_row3_col2, #T_3d14e_row3_col3, #T_3d14e_row3_col4, #T_3d14e_row3_col5, #T_3d14e_row3_col6, #T_3d14e_row4_col1, #T_3d14e_row4_col2, #T_3d14e_row4_col4, #T_3d14e_row4_col5, #T_3d14e_row5_col1, #T_3d14e_row5_col2, #T_3d14e_row5_col4, #T_3d14e_row5_col5, #T_3d14e_row6_col1, #T_3d14e_row6_col2, #T_3d14e_row6_col4, #T_3d14e_row6_col5, #T_3d14e_row7_col1, #T_3d14e_row7_col2 {
#   background-color: #3f007d;
#   color: #f1f1f1;
# }
# #T_3d14e_row1_col3 {
#   background-color: #440981;
#   color: #f1f1f1;
# }
# #T_3d14e_row1_col6, #T_3d14e_row5_col3, #T_3d14e_row6_col6 {
#   background-color: #430780;
#   color: #f1f1f1;
# }
# #T_3d14e_row2_col0 {
#   background-color: #705eaa;
#   color: #f1f1f1;
# }
# #T_3d14e_row2_col3 {
#   background-color: #41047f;
#   color: #f1f1f1;
# }
# #T_3d14e_row2_col6 {
#   background-color: #460c83;
#   color: #f1f1f1;
# }
# #T_3d14e_row4_col0 {
#   background-color: #6a51a3;
#   color: #f1f1f1;
# }
# #T_3d14e_row4_col3 {
#   background-color: #420680;
#   color: #f1f1f1;
# }
# #T_3d14e_row4_col6, #T_3d14e_row7_col4, #T_3d14e_row7_col5 {
#   background-color: #40017e;
#   color: #f1f1f1;
# }
# #T_3d14e_row5_col6 {
#   background-color: #40027e;
#   color: #f1f1f1;
# }
# #T_3d14e_row6_col0 {
#   background-color: #dadaeb;
#   color: #000000;
# }
# #T_3d14e_row6_col3 {
#   background-color: #450b82;
#   color: #f1f1f1;
# }
# #T_3d14e_row7_col3 {
#   background-color: #4c1788;
#   color: #f1f1f1;
# }
# #T_3d14e_row7_col6 {
#   background-color: #8481bc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3d14e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3d14e_level0_col0" class="col_heading level0 col0" >PassengerId</th>
#       <th id="T_3d14e_level0_col1" class="col_heading level0 col1" >Survived</th>
#       <th id="T_3d14e_level0_col2" class="col_heading level0 col2" >Pclass</th>
#       <th id="T_3d14e_level0_col3" class="col_heading level0 col3" >Age</th>
#       <th id="T_3d14e_level0_col4" class="col_heading level0 col4" >SibSp</th>
#       <th id="T_3d14e_level0_col5" class="col_heading level0 col5" >Parch</th>
#       <th id="T_3d14e_level0_col6" class="col_heading level0 col6" >Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3d14e_level0_row0" class="row_heading level0 row0" >count</th>
#       <td id="T_3d14e_row0_col0" class="data row0 col0" >1309.000000</td>
#       <td id="T_3d14e_row0_col1" class="data row0 col1" >891.000000</td>
#       <td id="T_3d14e_row0_col2" class="data row0 col2" >1309.000000</td>
#       <td id="T_3d14e_row0_col3" class="data row0 col3" >1046.000000</td>
#       <td id="T_3d14e_row0_col4" class="data row0 col4" >1309.000000</td>
#       <td id="T_3d14e_row0_col5" class="data row0 col5" >1309.000000</td>
#       <td id="T_3d14e_row0_col6" class="data row0 col6" >1308.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_3d14e_row1_col0" class="data row1 col0" >655.000000</td>
#       <td id="T_3d14e_row1_col1" class="data row1 col1" >0.383838</td>
#       <td id="T_3d14e_row1_col2" class="data row1 col2" >2.294882</td>
#       <td id="T_3d14e_row1_col3" class="data row1 col3" >29.881138</td>
#       <td id="T_3d14e_row1_col4" class="data row1 col4" >0.498854</td>
#       <td id="T_3d14e_row1_col5" class="data row1 col5" >0.385027</td>
#       <td id="T_3d14e_row1_col6" class="data row1 col6" >33.295479</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_3d14e_row2_col0" class="data row2 col0" >378.020061</td>
#       <td id="T_3d14e_row2_col1" class="data row2 col1" >0.486592</td>
#       <td id="T_3d14e_row2_col2" class="data row2 col2" >0.837836</td>
#       <td id="T_3d14e_row2_col3" class="data row2 col3" >14.413493</td>
#       <td id="T_3d14e_row2_col4" class="data row2 col4" >1.041658</td>
#       <td id="T_3d14e_row2_col5" class="data row2 col5" >0.865560</td>
#       <td id="T_3d14e_row2_col6" class="data row2 col6" >51.758668</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_3d14e_row3_col0" class="data row3 col0" >1.000000</td>
#       <td id="T_3d14e_row3_col1" class="data row3 col1" >0.000000</td>
#       <td id="T_3d14e_row3_col2" class="data row3 col2" >1.000000</td>
#       <td id="T_3d14e_row3_col3" class="data row3 col3" >0.170000</td>
#       <td id="T_3d14e_row3_col4" class="data row3 col4" >0.000000</td>
#       <td id="T_3d14e_row3_col5" class="data row3 col5" >0.000000</td>
#       <td id="T_3d14e_row3_col6" class="data row3 col6" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row4" class="row_heading level0 row4" >25%</th>
#       <td id="T_3d14e_row4_col0" class="data row4 col0" >328.000000</td>
#       <td id="T_3d14e_row4_col1" class="data row4 col1" >0.000000</td>
#       <td id="T_3d14e_row4_col2" class="data row4 col2" >2.000000</td>
#       <td id="T_3d14e_row4_col3" class="data row4 col3" >21.000000</td>
#       <td id="T_3d14e_row4_col4" class="data row4 col4" >0.000000</td>
#       <td id="T_3d14e_row4_col5" class="data row4 col5" >0.000000</td>
#       <td id="T_3d14e_row4_col6" class="data row4 col6" >7.895800</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row5" class="row_heading level0 row5" >50%</th>
#       <td id="T_3d14e_row5_col0" class="data row5 col0" >655.000000</td>
#       <td id="T_3d14e_row5_col1" class="data row5 col1" >0.000000</td>
#       <td id="T_3d14e_row5_col2" class="data row5 col2" >3.000000</td>
#       <td id="T_3d14e_row5_col3" class="data row5 col3" >28.000000</td>
#       <td id="T_3d14e_row5_col4" class="data row5 col4" >0.000000</td>
#       <td id="T_3d14e_row5_col5" class="data row5 col5" >0.000000</td>
#       <td id="T_3d14e_row5_col6" class="data row5 col6" >14.454200</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row6" class="row_heading level0 row6" >75%</th>
#       <td id="T_3d14e_row6_col0" class="data row6 col0" >982.000000</td>
#       <td id="T_3d14e_row6_col1" class="data row6 col1" >1.000000</td>
#       <td id="T_3d14e_row6_col2" class="data row6 col2" >3.000000</td>
#       <td id="T_3d14e_row6_col3" class="data row6 col3" >39.000000</td>
#       <td id="T_3d14e_row6_col4" class="data row6 col4" >1.000000</td>
#       <td id="T_3d14e_row6_col5" class="data row6 col5" >0.000000</td>
#       <td id="T_3d14e_row6_col6" class="data row6 col6" >31.275000</td>
#     </tr>
#     <tr>
#       <th id="T_3d14e_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_3d14e_row7_col0" class="data row7 col0" >1309.000000</td>
#       <td id="T_3d14e_row7_col1" class="data row7 col1" >1.000000</td>
#       <td id="T_3d14e_row7_col2" class="data row7 col2" >3.000000</td>
#       <td id="T_3d14e_row7_col3" class="data row7 col3" >80.000000</td>
#       <td id="T_3d14e_row7_col4" class="data row7 col4" >8.000000</td>
#       <td id="T_3d14e_row7_col5" class="data row7 col5" >9.000000</td>
#       <td id="T_3d14e_row7_col6" class="data row7 col6" >512.329200</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Creating the df where we will process the ML models
df = pd.DataFrame()

# %% [markdown]
# # Creating a function to help you visualize the information for each column

# %%
def titanic_analytics (data, column, number=True):
    print(f"Number of single values: {data[column].nunique()}")
    print(f"\nWhat are the unique values: {data[column].unique()}")
    print(f"\nNumber quantity missing: {data[column].isnull().sum()}")
    print(f"\nQuantity by option:  \n{data[column].value_counts()}")
    
    if number == True:
        sns.countplot(data = data, x= column, hue = 'Survived')
    else:
        sns.displot(data[column], kde=True)

# %% [markdown]
# # Analise de campos

# %% [markdown]
# ## Survived

# %%
titanic_analytics(titanic_df, 'Survived')
# Out:
# Number of single values: 2
#
# What are the unique values: [ 0.  1. nan]
#
# Number quantity missing: 418
#
# Quantity by option:
# 0.0    549
# 1.0    342
# Name: Survived, dtype: int64

# %%
df['Survived'] = titanic_df['Survived']
df
# Out:
#       Survived
# 0          0.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          0.0
# ...        ...
# 1304       NaN
# 1305       NaN
# 1306       NaN
# 1307       NaN
# 1308       NaN
#
# [1309 rows x 1 columns]

# %% [markdown]
# ## Pclass

# %%
titanic_analytics(titanic_df, 'Pclass')
# Out:
# Number of single values: 3
#
# What are the unique values: [3 1 2]
#
# Number quantity missing: 0
#
# Quantity by option:
# 3    709
# 1    323
# 2    277
# Name: Pclass, dtype: int64

# %%
df['Pclass']=titanic_df['Pclass']
df
# Out:
#       Survived  Pclass
# 0          0.0       3
# 1          1.0       1
# 2          1.0       3
# 3          1.0       1
# 4          0.0       3
# ...        ...     ...
# 1304       NaN       3
# 1305       NaN       1
# 1306       NaN       3
# 1307       NaN       3
# 1308       NaN       3
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## Name

# %%
titanic_df['Name'].sample(10)
# Out:
# 1116    Moubarek, Mrs. George (Omine Amenia" Alexander)"
# 30                              Uruchurtu, Don. Manuel E
# 859                                     Razi, Mr. Raihed
# 899            Abrahim, Mrs. Joseph (Sophie Halaut Easu)
# 566                                 Stoytcheff, Mr. Ilia
# 275                    Andrews, Miss. Kornelia Theodosia
# 1308                            Peter, Master. Michael J
# 1201                                Cacic, Mr. Jego Grga
# 536                    Butt, Major. Archibald Willingham
# 337                      Burns, Miss. Elizabeth Margaret
# Name: Name, dtype: object

# %% [markdown]
# ### Title

# %%
# Create feature Title
titanic_df['Title']=titanic_df['Name'].apply(lambda name: name.split(',')[1].split('.')[0].strip())
titanic_df['Title']
# Out:
# 0           Mr
# 1          Mrs
# 2         Miss
# 3          Mrs
# 4           Mr
#          ...
# 1304        Mr
# 1305      Dona
# 1306        Mr
# 1307        Mr
# 1308    Master
# Name: Title, Length: 1309, dtype: object

# %%
titanic_analytics(titanic_df, 'Title')
# Out:
# Number of single values: 18
#
# What are the unique values: ['Mr' 'Mrs' 'Miss' 'Master' 'Don' 'Rev' 'Dr' 'Mme' 'Ms' 'Major' 'Lady'
#  'Sir' 'Mlle' 'Col' 'Capt' 'the Countess' 'Jonkheer' 'Dona']
#
# Number quantity missing: 0
#
# Quantity by option:
# Mr              757
# Miss            260
# Mrs             197
# Master           61
# Rev               8
# Dr                8
# Col               4
# Mlle              2
# Major             2
# Ms                2
# Lady              1
# Sir               1
# Mme               1
# Don               1
# Capt              1
# the Countess      1
# Jonkheer          1
# Dona              1
# Name: Title, dtype: int64

# %%
# Agrupando dos titulos de baixa frequência
titanic_df['Title'] = [n if n in ['Mr', 'Mrs', 'Miss', 'Master'] else 'Others' for n in titanic_df['Title'] ]
titanic_df['Title']
# Out:
# 0           Mr
# 1          Mrs
# 2         Miss
# 3          Mrs
# 4           Mr
#          ...
# 1304        Mr
# 1305    Others
# 1306        Mr
# 1307        Mr
# 1308    Master
# Name: Title, Length: 1309, dtype: object

# %%
title = titanic_df['Title'].value_counts()
title
# Out:
# Mr        757
# Miss      260
# Mrs       197
# Master     61
# Others     34
# Name: Title, dtype: int64

# %%
title.plot(kind='pie', autopct='%1.1f%%', figsize=(8,5))
plt.title("Participação por título")

;
# Out:
# ''

# %%
titanic_analytics(titanic_df, 'Title')
# Out:
# Number of single values: 5
#
# What are the unique values: ['Mr' 'Mrs' 'Miss' 'Master' 'Others']
#
# Number quantity missing: 0
#
# Quantity by option:
# Mr        757
# Miss      260
# Mrs       197
# Master     61
# Others     34
# Name: Title, dtype: int64

# %%
df['Title']=titanic_df['Title']
df
# Out:
#       Survived  Pclass   Title
# 0          0.0       3      Mr
# 1          1.0       1     Mrs
# 2          1.0       3    Miss
# 3          1.0       1     Mrs
# 4          0.0       3      Mr
# ...        ...     ...     ...
# 1304       NaN       3      Mr
# 1305       NaN       1  Others
# 1306       NaN       3      Mr
# 1307       NaN       3      Mr
# 1308       NaN       3  Master
#
# [1309 rows x 3 columns]

# %% [markdown]
# ## Sex

# %%
titanic_analytics(titanic_df, 'Sex')
# Out:
# Number of single values: 2
#
# What are the unique values: ['male' 'female']
#
# Number quantity missing: 0
#
# Quantity by option:
# male      843
# female    466
# Name: Sex, dtype: int64

# %%
df['Sex']=titanic_df['Sex']
df
# Out:
#       Survived  Pclass   Title     Sex
# 0          0.0       3      Mr    male
# 1          1.0       1     Mrs  female
# 2          1.0       3    Miss  female
# 3          1.0       1     Mrs  female
# 4          0.0       3      Mr    male
# ...        ...     ...     ...     ...
# 1304       NaN       3      Mr    male
# 1305       NaN       1  Others  female
# 1306       NaN       3      Mr    male
# 1307       NaN       3      Mr    male
# 1308       NaN       3  Master    male
#
# [1309 rows x 4 columns]

# %% [markdown]
# ## Age

# %%
titanic_analytics(titanic_df, 'Age', False)
# Out:
# Number of single values: 98
#
# What are the unique values: [22.   38.   26.   35.     nan 54.    2.   27.   14.    4.   58.   20.
#  39.   55.   31.   34.   15.   28.    8.   19.   40.   66.   42.   21.
#  18.    3.    7.   49.   29.   65.   28.5   5.   11.   45.   17.   32.
#  16.   25.    0.83 30.   33.   23.   24.   46.   59.   71.   37.   47.
#  14.5  70.5  32.5  12.    9.   36.5  51.   55.5  40.5  44.    1.   61.
#  56.   50.   36.   45.5  20.5  62.   41.   52.   63.   23.5   0.92 43.
#  60.   10.   64.   13.   48.    0.75 53.   57.   80.   70.   24.5   6.
#   0.67 30.5   0.42 34.5  74.   22.5  18.5  67.   76.   26.5  60.5  11.5
#   0.33  0.17 38.5 ]
#
# Number quantity missing: 263
#
# Quantity by option:
# 24.0    47
# 22.0    43
# 21.0    41
# 30.0    40
# 18.0    39
#         ..
# 23.5     1
# 70.5     1
# 55.5     1
# 20.5     1
# 38.5     1
# Name: Age, Length: 98, dtype: int64

# %% [markdown]
# ### Tratando dados NULOS

# %%
titanic_df
# Out:
#       PassengerId  Survived  Pclass  \
# 0               1       0.0       3
# 1               2       1.0       1
# 2               3       1.0       3
# 3               4       1.0       1
# 4               5       0.0       3
# ...           ...       ...     ...
# 1304         1305       NaN       3
# 1305         1306       NaN       1
# 1306         1307       NaN       3
# 1307         1308       NaN       3
# 1308         1309       NaN       3
#
#                                                    Name     Sex   Age  SibSp  \
# 0                               Braund, Mr. Owen Harris    male  22.0      1
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                                Heikkinen, Miss. Laina  female  26.0      0
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                              Allen, Mr. William Henry    male  35.0      0
# ...                                                 ...     ...   ...    ...
# 1304                                 Spector, Mr. Woolf    male   NaN      0
# 1305                       Oliva y Ocana, Dona. Fermina  female  39.0      0
# 1306                       Saether, Mr. Simon Sivertsen    male  38.5      0
# 1307                                Ware, Mr. Frederick    male   NaN      0
# 1308                           Peter, Master. Michael J    male   NaN      1
#
#       Parch              Ticket      Fare Cabin Embarked   Title
# 0         0           A/5 21171    7.2500   NaN        S      Mr
# 1         0            PC 17599   71.2833   C85        C     Mrs
# 2         0    STON/O2. 3101282    7.9250   NaN        S    Miss
# 3         0              113803   53.1000  C123        S     Mrs
# 4         0              373450    8.0500   NaN        S      Mr
# ...     ...                 ...       ...   ...      ...     ...
# 1304      0           A.5. 3236    8.0500   NaN        S      Mr
# 1305      0            PC 17758  108.9000  C105        C  Others
# 1306      0  SOTON/O.Q. 3101262    7.2500   NaN        S      Mr
# 1307      0              359309    8.0500   NaN        S      Mr
# 1308      1                2668   22.3583   NaN        C  Master
#
# [1309 rows x 13 columns]

# %%
titanic_df.loc[titanic_df['Title'] == 'Mr', 'Age'].mean()
# Out:
# 32.25215146299484

# %%
for i in (titanic_df['Title'].unique()):
    print(f"Pesoas com o título {i} tem a média de idade de: {titanic_df.loc[titanic_df['Title'] == i, 'Age'].mean():.2f} ")
# Out:
# Pesoas com o título Mr tem a média de idade de: 32.25
# Pesoas com o título Mrs tem a média de idade de: 36.99
# Pesoas com o título Miss tem a média de idade de: 21.77
# Pesoas com o título Master tem a média de idade de: 5.48
# Pesoas com o título Others tem a média de idade de: 42.66

# %%
titanic_df.loc[(titanic_df['Title']=='Mr') & (titanic_df['Age'].isna()), 'Age'] = round(titanic_df.loc[titanic_df['Title'] == 'Mr', 'Age'].mean(),0)
titanic_df.loc[(titanic_df['Title']=='Mrs') & (titanic_df['Age'].isna()), 'Age'] = round(titanic_df.loc[titanic_df['Title'] == 'Mrs', 'Age'].mean(),0)
titanic_df.loc[(titanic_df['Title']=='Miss') & (titanic_df['Age'].isna()), 'Age'] = round(titanic_df.loc[titanic_df['Title'] == 'Miss', 'Age'].mean(),0)
titanic_df.loc[(titanic_df['Title']=='Master') & (titanic_df['Age'].isna()), 'Age'] = round(titanic_df.loc[titanic_df['Title'] == 'Master', 'Age'].mean(),0)
titanic_df.loc[(titanic_df['Title']=='Others') & (titanic_df['Age'].isna()), 'Age'] = round(titanic_df.loc[titanic_df['Title'] == 'Others', 'Age'].mean(),0)

# %%
titanic_df.isnull().sum()
# Out:
# PassengerId       0
# Survived        418
# Pclass            0
# Name              0
# Sex               0
# Age               0
# SibSp             0
# Parch             0
# Ticket            0
# Fare              1
# Cabin          1014
# Embarked          2
# Title             0
# dtype: int64

# %%
titanic_df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked', 'Title'],
#       dtype='object')

# %%
df['Age']=titanic_df['Age']
df
# Out:
#       Survived  Pclass   Title     Sex   Age
# 0          0.0       3      Mr    male  22.0
# 1          1.0       1     Mrs  female  38.0
# 2          1.0       3    Miss  female  26.0
# 3          1.0       1     Mrs  female  35.0
# 4          0.0       3      Mr    male  35.0
# ...        ...     ...     ...     ...   ...
# 1304       NaN       3      Mr    male  32.0
# 1305       NaN       1  Others  female  39.0
# 1306       NaN       3      Mr    male  38.5
# 1307       NaN       3      Mr    male  32.0
# 1308       NaN       3  Master    male   5.0
#
# [1309 rows x 5 columns]

# %% [markdown]
# ### Score_Age
# Agrupando por grupo por faixa de idade
# 1. 0 - 13
# 2. 13 - 23
# 3. 23 - 35
# 4. 35 - 50
# 5. maior que 60

# %%
titanic_df['Score_Age'] = 0
age = titanic_df['Age']

# %%
for index, value in enumerate(age):
    if  value <= 13.0:
        print(1)
        titanic_df.iloc[index,13] = 1
    if  value >= 14 and value <=23:
        print(2)
        titanic_df.iloc[index,13] = 2
    if value >= 24 and value <= 35:
        print(3)
        titanic_df.iloc[index,13] = 3
    if value >= 36 and row['Age'] <= 50:
        print(4)
        titanic_df.iloc[index,13] = 4
    if value > 50:
        titanic_df.iloc[index,13] = 5

# %%
titanic_analytics(titanic_df, 'Score_Age')
# Out:
# Number of single values: 5
#
# What are the unique values: [2 4 3 5 1]
#
# Number quantity missing: 0
#
# Quantity by option:
# 3    539
# 2    311
# 4    256
# 1    107
# 5     96
# Name: Score_Age, dtype: int64

# %%
df['Score_Age'] = titanic_df['Score_Age']
df
# Out:
#       Survived  Pclass   Title     Sex   Age  Score_Age
# 0          0.0       3      Mr    male  22.0          2
# 1          1.0       1     Mrs  female  38.0          4
# 2          1.0       3    Miss  female  26.0          3
# 3          1.0       1     Mrs  female  35.0          3
# 4          0.0       3      Mr    male  35.0          3
# ...        ...     ...     ...     ...   ...        ...
# 1304       NaN       3      Mr    male  32.0          3
# 1305       NaN       1  Others  female  39.0          4
# 1306       NaN       3      Mr    male  38.5          4
# 1307       NaN       3      Mr    male  32.0          3
# 1308       NaN       3  Master    male   5.0          1
#
# [1309 rows x 6 columns]

# %% [markdown]
# ## SibSp

# %%
titanic_analytics(titanic_df, 'SibSp')
# Out:
# Number of single values: 7
#
# What are the unique values: [1 0 3 4 2 5 8]
#
# Number quantity missing: 0
#
# Quantity by option:
# 0    891
# 1    319
# 2     42
# 4     22
# 3     20
# 8      9
# 5      6
# Name: SibSp, dtype: int64

# %%
df['SibSp'] = titanic_df['SibSp']
df
# Out:
#       Survived  Pclass   Title     Sex   Age  Score_Age  SibSp
# 0          0.0       3      Mr    male  22.0          2      1
# 1          1.0       1     Mrs  female  38.0          4      1
# 2          1.0       3    Miss  female  26.0          3      0
# 3          1.0       1     Mrs  female  35.0          3      1
# 4          0.0       3      Mr    male  35.0          3      0
# ...        ...     ...     ...     ...   ...        ...    ...
# 1304       NaN       3      Mr    male  32.0          3      0
# 1305       NaN       1  Others  female  39.0          4      0
# 1306       NaN       3      Mr    male  38.5          4      0
# 1307       NaN       3      Mr    male  32.0          3      0
# 1308       NaN       3  Master    male   5.0          1      1
#
# [1309 rows x 7 columns]

# %% [markdown]
# ## Parch

# %%
titanic_analytics(titanic_df, 'Parch')
# Out:
# Number of single values: 8
#
# What are the unique values: [0 1 2 5 3 4 6 9]
#
# Number quantity missing: 0
#
# Quantity by option:
# 0    1002
# 1     170
# 2     113
# 3       8
# 5       6
# 4       6
# 6       2
# 9       2
# Name: Parch, dtype: int64

# %%
df['Parch'] = titanic_df['Parch']
df
# Out:
#       Survived  Pclass   Title     Sex   Age  Score_Age  SibSp  Parch
# 0          0.0       3      Mr    male  22.0          2      1      0
# 1          1.0       1     Mrs  female  38.0          4      1      0
# 2          1.0       3    Miss  female  26.0          3      0      0
# 3          1.0       1     Mrs  female  35.0          3      1      0
# 4          0.0       3      Mr    male  35.0          3      0      0
# ...        ...     ...     ...     ...   ...        ...    ...    ...
# 1304       NaN       3      Mr    male  32.0          3      0      0
# 1305       NaN       1  Others  female  39.0          4      0      0
# 1306       NaN       3      Mr    male  38.5          4      0      0
# 1307       NaN       3      Mr    male  32.0          3      0      0
# 1308       NaN       3  Master    male   5.0          1      1      1
#
# [1309 rows x 8 columns]

# %% [markdown]
# ### FamilySize

# %%
titanic_df['FamilySize'] = titanic_df['SibSp']+titanic_df['Parch'] + 1
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1       0.0       3
# 1            2       1.0       1
# 2            3       1.0       3
# 3            4       1.0       1
# 4            5       0.0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Score_Age  \
# 0      0         A/5 21171   7.2500   NaN        S    Mr          2
# 1      0          PC 17599  71.2833   C85        C   Mrs          4
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss          3
# 3      0            113803  53.1000  C123        S   Mrs          3
# 4      0            373450   8.0500   NaN        S    Mr          3
#
#    FamilySize
# 0           2
# 1           2
# 2           1
# 3           2
# 4           1

# %%
titanic_analytics(titanic_df, 'FamilySize')
# Out:
# Number of single values: 9
#
# What are the unique values: [ 2  1  5  3  7  6  4  8 11]
#
# Number quantity missing: 0
#
# Quantity by option:
# 1     790
# 2     235
# 3     159
# 4      43
# 6      25
# 5      22
# 7      16
# 11     11
# 8       8
# Name: FamilySize, dtype: int64

# %%
df['FamilySize'] =  titanic_df['FamilySize']
df
# Out:
#       Survived  Pclass   Title     Sex   Age  Score_Age  SibSp  Parch  \
# 0          0.0       3      Mr    male  22.0          2      1      0
# 1          1.0       1     Mrs  female  38.0          4      1      0
# 2          1.0       3    Miss  female  26.0          3      0      0
# 3          1.0       1     Mrs  female  35.0          3      1      0
# 4          0.0       3      Mr    male  35.0          3      0      0
# ...        ...     ...     ...     ...   ...        ...    ...    ...
# 1304       NaN       3      Mr    male  32.0          3      0      0
# 1305       NaN       1  Others  female  39.0          4      0      0
# 1306       NaN       3      Mr    male  38.5          4      0      0
# 1307       NaN       3      Mr    male  32.0          3      0      0
# 1308       NaN       3  Master    male   5.0          1      1      1
#
#       FamilySize
# 0              2
# 1              2
# 2              1
# 3              2
# 4              1
# ...          ...
# 1304           1
# 1305           1
# 1306           1
# 1307           1
# 1308           3
#
# [1309 rows x 9 columns]

# %% [markdown]
# ## fare

# %%
titanic_analytics(titanic_df, 'Fare', False)
# Out:
# Number of single values: 281
#
# What are the unique values: [  7.25    71.2833   7.925   53.1      8.05     8.4583  51.8625  21.075
#   11.1333  30.0708  16.7     26.55    31.275    7.8542  16.      29.125
#   13.      18.       7.225   26.       8.0292  35.5     31.3875 263.
#    7.8792   7.8958  27.7208 146.5208   7.75    10.5     82.1708  52.
#    7.2292  11.2417   9.475   21.      41.5792  15.5     21.6792  17.8
#   39.6875   7.8     76.7292  61.9792  27.75    46.9     80.      83.475
#   27.9     15.2458   8.1583   8.6625  73.5     14.4542  56.4958   7.65
#   29.      12.475    9.       9.5      7.7875  47.1     15.85    34.375
#   61.175   20.575   34.6542  63.3583  23.      77.2875   8.6542   7.775
#   24.15     9.825   14.4583 247.5208   7.1417  22.3583   6.975    7.05
#   14.5     15.0458  26.2833   9.2167  79.2      6.75    11.5     36.75
#    7.7958  12.525   66.6      7.3125  61.3792   7.7333  69.55    16.1
#   15.75    20.525   55.      25.925   33.5     30.6958  25.4667  28.7125
#    0.      15.05    39.      22.025   50.       8.4042   6.4958  10.4625
#   18.7875  31.     113.275   27.      76.2917  90.       9.35    13.5
#    7.55    26.25    12.275    7.125   52.5542  20.2125  86.5    512.3292
#   79.65   153.4625 135.6333  19.5     29.7     77.9583  20.25    78.85
#   91.0792  12.875    8.85   151.55    30.5     23.25    12.35   110.8833
#  108.9     24.      56.9292  83.1583 262.375   14.     164.8667 134.5
#    6.2375  57.9792  28.5    133.65    15.9      9.225   35.      75.25
#   69.3     55.4417 211.5      4.0125 227.525   15.7417   7.7292  12.
#  120.      12.65    18.75     6.8583  32.5      7.875   14.4     55.9
#    8.1125  81.8583  19.2583  19.9667  89.1042  38.5      7.725   13.7917
#    9.8375   7.0458   7.5208  12.2875   9.5875  49.5042  78.2667  15.1
#    7.6292  22.525   26.2875  59.4      7.4958  34.0208  93.5    221.7792
#  106.425   49.5     71.      13.8625   7.8292  39.6     17.4     51.4792
#   26.3875  30.      40.125    8.7125  15.      33.      42.4     15.55
#   65.      32.3208   7.0542   8.4333  25.5875   9.8417   8.1375  10.1708
#  211.3375  57.      13.4167   7.7417   9.4833   7.7375   8.3625  23.45
#   25.9292   8.6833   8.5167   7.8875  37.0042   6.45     6.95     8.3
#    6.4375  39.4     14.1083  13.8583  50.4958   5.       9.8458  10.5167
#    7.       9.6875  82.2667   3.1708  31.6833  31.5     57.75     7.85
#   60.      15.0333  15.5792  28.5375  25.7     10.7083  13.9      7.8208
#    7.7792  31.6792   7.2833  75.2417      nan  12.1833  13.775    8.9625
#   25.7417  42.5     27.4458 136.7792   9.325   12.7375  45.5      7.575
#    7.5792   7.7208]
#
# Number quantity missing: 1
#
# Quantity by option:
# 8.0500     60
# 13.0000    59
# 7.7500     55
# 26.0000    50
# 7.8958     49
#            ..
# 7.7417      1
# 8.1583      1
# 8.4583      1
# 7.8000      1
# 7.7208      1
# Name: Fare, Length: 281, dtype: int64

# %% [markdown]
# ### Tratando dados Nulos

# %%
titanic_df[titanic_df['Fare'].isnull()]
# Out:
#       PassengerId  Survived  Pclass                Name   Sex   Age  SibSp  \
# 1043         1044       NaN       3  Storey, Mr. Thomas  male  60.5      0
#
#       Parch Ticket  Fare Cabin Embarked Title  Score_Age  FamilySize
# 1043      0   3701   NaN   NaN        S    Mr          5           1

# %%
# vamos adicionar a mẽdia baseado em Pclass
media_fare = round(titanic_df.loc[titanic_df['Pclass'] == 3, 'Fare'].mean(),2)

# %%
titanic_df['Fare'].fillna(media_fare, inplace=True)

# %%
titanic_df[titanic_df['Fare'].isnull()]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title, Score_Age, FamilySize]
# Index: []

# %%
df['Fare'] = titanic_df['Fare']

# %%
df
# Out:
#       Survived  Pclass   Title     Sex   Age  Score_Age  SibSp  Parch  \
# 0          0.0       3      Mr    male  22.0          2      1      0
# 1          1.0       1     Mrs  female  38.0          4      1      0
# 2          1.0       3    Miss  female  26.0          3      0      0
# 3          1.0       1     Mrs  female  35.0          3      1      0
# 4          0.0       3      Mr    male  35.0          3      0      0
# ...        ...     ...     ...     ...   ...        ...    ...    ...
# 1304       NaN       3      Mr    male  32.0          3      0      0
# 1305       NaN       1  Others  female  39.0          4      0      0
# 1306       NaN       3      Mr    male  38.5          4      0      0
# 1307       NaN       3      Mr    male  32.0          3      0      0
# 1308       NaN       3  Master    male   5.0          1      1      1
#
#       FamilySize      Fare
# 0              2    7.2500
# 1              2   71.2833
# 2              1    7.9250
# 3              2   53.1000
# 4              1    8.0500
# ...          ...       ...
# 1304           1    8.0500
# 1305           1  108.9000
# 1306           1    7.2500
# 1307           1    8.0500
# 1308           3   22.3583
#
# [1309 rows x 10 columns]

# %% [markdown]
# ## Cabin
# Como esta variavel tem muitos dados nulos nós não vamos usado
